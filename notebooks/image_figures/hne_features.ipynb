# %%
import scanpy as sc
import squidpy as sq
import os
import anndata as ad
import tqdm
import itertools as it
import matplotlib.pyplot as plt
import pandas as pd

import skimage.exposure
import numpy as np
# Out:
# /Users/hannah.spitzer/opt/miniconda3/envs/squidpy/lib/python3.8/site-packages/napari/__init__.py:44: UserWarning:
#     napari was tested with QT library `>=5.12.3`.
#     The version installed is 5.9.7. Please report any issues with this
#     specific QT version at https://github.com/Napari/napari/issues.
#
#   warn(message=warn_message)

# %%
# get spatial dataset including hires tissue image
img = sq.datasets.visium_hne_image(chunks=2000)
adata = sq.datasets.visium_hne_adata()

# %% [markdown]
# ## Prepare features and clusters
# save calculated clusters for later use

# %%
# define different feature calculation combinations
params = {
    # all features, corresponding only to tissue underneath spot
    'features_orig': 
    {'features': 'summary',
    'spot_scale': 1,
    'scale': 1.0,
    'mask_circle': True},
    # summary and histogram features with a bit more context, original resolution
    'features_context': 
    {'features': 'summary',
    'spot_scale': 2,
    'scale': 1.0},
    # summary and histogram features with more context and at lower resolution
    'features_lowres' :
    {'features': 'summary',
    'spot_scale': 4,
    'scale': 0.25}
}

# %%
# extract features with the different parameters in a loop
for feature_name, cur_params in tqdm.tqdm(params.items()):
    # features will be saved in `adata.obsm[feature_name]`
    sq.im.calculate_image_features(adata, img, key_added=feature_name, n_jobs=4, **cur_params)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2688.0), HTML(value='')))
#  33%|███▎      | 1/3 [00:29<00:58, 29.29s/it]
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2688.0), HTML(value='')))
#  67%|██████▋   | 2/3 [00:50<00:26, 26.82s/it]
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2688.0), HTML(value='')))
# 100%|██████████| 3/3 [01:22<00:00, 27.56s/it]

# %%
# fill nans
adata.obsm['features_orig'].fillna(value=0, inplace=True)
# combine features in one dataframe
adata.obsm['features'] = pd.concat([adata.obsm[f] for f in params.keys()], axis='columns')
# make sure that we have no duplicated feature names in the combined table
adata.obsm['features'].columns = ad.utils.make_index_unique(adata.obsm['features'].columns)

# %%
# helper function returning a clustering
def cluster_features(features, like=None):
    """Calculate leiden clustering of features.
    
    Specify filter of features using `like`.
    """
    # filter features
    if like is not None:
        features = features.filter(like=like)
    # create temporary adata to calculate the clustering
    adata = ad.AnnData(features)
    # important - feature values are not scaled, so need to scale them before PCA
    sc.pp.scale(adata)
    # calculate leiden clustering
    sc.pp.pca(adata, n_comps=min(10, features.shape[1]-1))
    sc.pp.neighbors(adata)
    sc.tl.leiden(adata)
    
    return adata.obs['leiden']

# %%
adata.obsm['features']
# Out:
#                     summary_ch-0_quantile-0.9  summary_ch-0_mean  \
# AAACAAGTATCTCCCA-1                      128.0          81.635021
# AAACAATCTACTAGCA-1                      136.0          84.346547
# AAACACCAATAACTGC-1                      130.0          86.132433
# AAACAGAGCGACTCCT-1                      133.0          87.976771
# AAACCGGGTAGGTACC-1                      134.0          84.600429
# ...                                       ...                ...
# TTGTTGTGTGTCAAGA-1                      131.0          73.408534
# TTGTTTCACATCCAGG-1                      135.0          79.204393
# TTGTTTCATTAGTCTA-1                      133.0          82.381770
# TTGTTTCCATACAACT-1                      134.0          84.076127
# TTGTTTGTGTAAATTC-1                      136.0          85.589446
#
#                     summary_ch-0_std  summary_ch-0_quantile-0.5  \
# AAACAAGTATCTCCCA-1         48.908836                      101.0
# AAACAATCTACTAGCA-1         51.212751                      102.0
# AAACACCAATAACTGC-1         50.397744                      110.0
# AAACAGAGCGACTCCT-1         50.927888                      110.0
# AAACCGGGTAGGTACC-1         50.231840                      103.0
# ...                              ...                        ...
# TTGTTGTGTGTCAAGA-1         50.523341                       88.0
# TTGTTTCACATCCAGG-1         50.544272                       94.0
# TTGTTTCATTAGTCTA-1         50.569260                      102.0
# TTGTTTCCATACAACT-1         50.168102                      103.0
# TTGTTTGTGTAAATTC-1         51.674587                      105.0
#
#                     summary_ch-0_quantile-0.1  summary_ch-1_quantile-0.9  \
# AAACAAGTATCTCCCA-1                        0.0                       97.0
# AAACAATCTACTAGCA-1                        0.0                       82.0
# AAACACCAATAACTGC-1                        0.0                      106.0
# AAACAGAGCGACTCCT-1                        0.0                      109.0
# AAACCGGGTAGGTACC-1                        0.0                      100.0
# ...                                       ...                        ...
# TTGTTGTGTGTCAAGA-1                        0.0                      100.0
# TTGTTTCACATCCAGG-1                        0.0                      108.0
# TTGTTTCATTAGTCTA-1                        0.0                      103.0
# TTGTTTCCATACAACT-1                        0.0                       96.0
# TTGTTTGTGTAAATTC-1                        0.0                      117.0
#
#                     summary_ch-1_mean  summary_ch-1_std  \
# AAACAAGTATCTCCCA-1          59.301730         36.731739
# AAACAATCTACTAGCA-1          46.911880         30.739451
# AAACACCAATAACTGC-1          68.189875         40.311883
# AAACAGAGCGACTCCT-1          63.908850         39.694211
# AAACCGGGTAGGTACC-1          60.288347         37.183073
# ...                               ...               ...
# TTGTTGTGTGTCAAGA-1          53.397298         37.708050
# TTGTTTCACATCCAGG-1          61.639818         40.177631
# TTGTTTCATTAGTCTA-1          61.330388         38.553518
# TTGTTTCCATACAACT-1          56.881202         35.427405
# TTGTTTGTGTAAATTC-1          71.257038         44.262038
#
#                     summary_ch-1_quantile-0.5  summary_ch-1_quantile-0.1  ...  \
# AAACAAGTATCTCCCA-1                       71.0                        0.0  ...
# AAACAATCTACTAGCA-1                       53.0                        0.0  ...
# AAACACCAATAACTGC-1                       85.0                        0.0  ...
# AAACAGAGCGACTCCT-1                       74.0                        0.0  ...
# AAACCGGGTAGGTACC-1                       71.0                        0.0  ...
# ...                                       ...                        ...  ...
# TTGTTGTGTGTCAAGA-1                       60.0                        0.0  ...
# TTGTTTCACATCCAGG-1                       70.0                        0.0  ...
# TTGTTTCATTAGTCTA-1                       72.0                        0.0  ...
# TTGTTTCCATACAACT-1                       66.0                        0.0  ...
# TTGTTTGTGTAAATTC-1                       85.0                        0.0  ...
#
#                     summary_ch-1_quantile-0.9-2  summary_ch-1_mean-2  \
# AAACAAGTATCTCCCA-1                         99.0            82.472495
# AAACAATCTACTAGCA-1                        130.0            75.813920
# AAACACCAATAACTGC-1                        105.0            85.756069
# AAACAGAGCGACTCCT-1                        129.0            91.740961
# AAACCGGGTAGGTACC-1                         93.0            76.228951
# ...                                         ...                  ...
# TTGTTGTGTGTCAAGA-1                         93.0            74.433497
# TTGTTTCACATCCAGG-1                         99.0            78.438404
# TTGTTTCATTAGTCTA-1                        102.0            81.893079
# TTGTTTCCATACAACT-1                         93.0            73.796358
# TTGTTTGTGTAAATTC-1                        104.0            80.346849
#
#                     summary_ch-1_std-2  summary_ch-1_quantile-0.5-2  \
# AAACAAGTATCTCCCA-1           15.717368                         83.0
# AAACAATCTACTAGCA-1           27.677953                         70.0
# AAACACCAATAACTGC-1           17.302733                         89.0
# AAACAGAGCGACTCCT-1           24.476055                         88.0
# AAACCGGGTAGGTACC-1           14.161658                         77.0
# ...                                ...                          ...
# TTGTTGTGTGTCAAGA-1           16.221947                         76.0
# TTGTTTCACATCCAGG-1           17.041903                         80.0
# TTGTTTCATTAGTCTA-1           16.790670                         83.0
# TTGTTTCCATACAACT-1           15.239496                         74.0
# TTGTTTGTGTAAATTC-1           18.831594                         80.0
#
#                     summary_ch-1_quantile-0.1-2  summary_ch-2_quantile-0.9-2  \
# AAACAAGTATCTCCCA-1                         63.0                        124.0
# AAACAATCTACTAGCA-1                         47.0                        128.0
# AAACACCAATAACTGC-1                         62.0                        127.0
# AAACAGAGCGACTCCT-1                         63.0                        126.0
# AAACCGGGTAGGTACC-1                         58.0                        125.0
# ...                                         ...                          ...
# TTGTTGTGTGTCAAGA-1                         52.0                        128.0
# TTGTTTCACATCCAGG-1                         56.0                        129.7
# TTGTTTCATTAGTCTA-1                         59.0                        127.0
# TTGTTTCCATACAACT-1                         54.0                        126.0
# TTGTTTGTGTAAATTC-1                         56.0                        128.0
#
#                     summary_ch-2_mean-2  summary_ch-2_std-2  \
# AAACAAGTATCTCCCA-1           111.793905           10.085181
# AAACAATCTACTAGCA-1           110.552944           16.176703
# AAACACCAATAACTGC-1           113.014850           12.642071
# AAACAGAGCGACTCCT-1           114.140108           11.012759
# AAACCGGGTAGGTACC-1           110.874742           12.282806
# ...                                 ...                 ...
# TTGTTGTGTGTCAAGA-1           110.778796           15.945818
# TTGTTTCACATCCAGG-1           111.287319           15.195488
# TTGTTTCATTAGTCTA-1           111.042226           13.608595
# TTGTTTCCATACAACT-1           109.589876           13.285279
# TTGTTTGTGTAAATTC-1           112.551007           13.088363
#
#                     summary_ch-2_quantile-0.5-2  summary_ch-2_quantile-0.1-2
# AAACAAGTATCTCCCA-1                        113.0                         99.0
# AAACAATCTACTAGCA-1                        112.0                         91.0
# AAACACCAATAACTGC-1                        115.0                         98.0
# AAACAGAGCGACTCCT-1                        116.0                        100.0
# AAACCGGGTAGGTACC-1                        112.0                         95.0
# ...                                         ...                          ...
# TTGTTGTGTGTCAAGA-1                        113.0                         90.0
# TTGTTTCACATCCAGG-1                        113.0                         92.0
# TTGTTTCATTAGTCTA-1                        112.0                         93.0
# TTGTTTCCATACAACT-1                        110.0                         93.0
# TTGTTTGTGTAAATTC-1                        114.0                         96.0
#
# [2688 rows x 45 columns]

# %%
# cluster features
adata.obs['features_cluster'] = cluster_features(adata.obsm['features'])

# save features clusters to always have the same clusters
adata.obs['features_cluster'].to_csv('features_cluster.csv')

# %% [markdown]
# ## Plot and save figs

# %%
# load features clusters in adata
adata.obs['features_cluster'] = pd.read_csv('features_cluster.csv', index_col=0)
adata.obs['features_cluster'] = adata.obs['features_cluster'].astype('category')

# %%
# make hne image a bit brighter
#img_png = adata.uns['spatial']['V1_Adult_Mouse_Brain']['images']['hires']
p2, p98 = np.percentile(img_png, (0.5, 99.5))
img_rescale = skimage.exposure.rescale_intensity(img_png, in_range=(p2, p98))

fig, axes = plt.subplots(1,2)
axes[0].imshow(img_rescale[500:1000,500:1000])
axes[1].imshow(img_png[500:1000,500:1000])

adata.uns['spatial']['V1_Adult_Mouse_Brain']['images']['hires'] = img_rescale

# %%
# plotting settings
sc.settings.dpi = 300
sc.set_figure_params(facecolor="white", fontsize=14)
# fontsize sets the size of the title

# %%
fig, ax = plt.subplots(
    figsize=(3, 5),
)
# plot hne
sc.pl.spatial(
    adata,
    color=None,
    img_key='hires',
    ax=ax,
    title='H&E stain',
    #legend_loc=False,
    show=False
)
ax.axes.xaxis.label.set_visible(False)
ax.axes.yaxis.label.set_visible(False)
# save figure
plt.tight_layout()
plt.savefig('figures/spatial_hne.png', dpi=300, bbox_inches='tight')

# %%
# plot gene clusters
fig, ax = plt.subplots(figsize=(3, 5))
sc.pl.spatial(
    adata,
    color='cluster',
    img_key='hires',
    ax=ax,
    alpha_img=0.2,
    bw=True,
    title='gene clusters',
    #legend_loc=False,
    show=False,
)
#ax.set_facecolor((0.75,0.75,0.75))
ax.axes.xaxis.label.set_visible(False)
ax.axes.yaxis.label.set_visible(False)
# get legend colors to plot later
colors, labels = ax.get_legend_handles_labels()
ax.get_legend().remove()
# save figure
plt.tight_layout()
plt.savefig('figures/spatial_cluster.png', dpi=300, bbox_inches='tight')

# plot and save legend
labels = [' '.join(l.split('_')) for l in labels]

fig, ax1 = plt.subplots(1,1, figsize=(3,5))
plt.figlegend(colors, labels, frameon=False, markerscale=1.5)
ax1.axis('off')
plt.tight_layout()
plt.savefig('figures/spatial_cluster_legend.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot feature clusters
fig, ax = plt.subplots(figsize=(3, 5))
sc.pl.spatial(
    adata,
    color='features_cluster',
    img_key='hires',
    ax=ax,
    alpha_img=0.2,
    bw=True,
    title='image feature clusters',
    #legend_loc=False,
    show=False
)
ax.axes.xaxis.label.set_visible(False)
ax.axes.yaxis.label.set_visible(False)
# get legend colors to plot later
colors, labels = ax.get_legend_handles_labels()
ax.get_legend().remove()
# save figure
plt.tight_layout()
plt.savefig('figures/spatial_features_cluster.png', dpi=300, bbox_inches='tight')

# plot and save legend
labels = [' '.join(l.split('_')) for l in labels]

fig, ax1 = plt.subplots(1,1, figsize=(3,5))
plt.figlegend(colors, labels, frameon=False, markerscale=1.5)
ax1.axis('off')
plt.tight_layout()
plt.savefig('figures/spatial_features_cluster_legend.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
def plot_gene(adata, g, remove=None):
    # plot genes
    fig, ax = plt.subplots(figsize=(3, 5))
    sc.pl.spatial(
        adata,
        color=g,
        img_key='hires',
        ax=ax,
        alpha_img=0.2,
        bw=True,
        #legend_loc=False,
        show=False,
        cmap='viridis'
    )
    ax.axes.xaxis.label.set_visible(False)
    ax.axes.yaxis.label.set_visible(False)
    # remove one axis
    if remove == 'plot':
        fig.get_axes()[0].remove()
    elif remove == 'legend':
        fig.get_axes()[1].remove()
    return ax

# %%
for g in ['Camk2n1', "Nrgn", "Mobp"]:
    # plot image
    ax = plot_gene(adata, g, remove='legend')
    plt.tight_layout()
    plt.savefig(f'figures/spatial_{g}.png', dpi=300, bbox_inches='tight')

    # plot legend
    ax = plot_gene(adata, g, remove='plot')
    plt.tight_layout()
    plt.savefig(f'figures/spatial_{g}_legend.png', dpi=300, bbox_inches='tight')
