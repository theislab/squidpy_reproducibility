# %% [markdown]
# ## CellPhoneDB installation
#
# - `git clone https://github.com/Teichlab/cellphonedb`
# - move this notebook into `cellphonedb` directory

# %% [markdown]
# # Imports

# %%
import sys
import cloudpickle as pickle
from time import process_time
from collections import defaultdict

from scipy.stats import pearsonr
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import scanpy as sc
import squidpy as sq
import scvelo as scv

# pip install -e. sqlalchmey fbpca geosketch werkzeug
#sys.path.insert(0, './cellphonedb/src/api_endpoints/terminal_api/method_terminal_api_endpoints/')
#from method_terminal_commands import statistical_analysis

# %% [markdown]
# # Utility

# %% [markdown]
# ## Functions

# %%
def save_data(adata):
    df_expr_matrix = adata.raw.X
    df_expr_matrix = df_expr_matrix.T
    df_expr_matrix = pd.DataFrame(df_expr_matrix)

    df_expr_matrix.columns= adata.obs.index
    df_expr_matrix.set_index(adata.raw.var.index, inplace=True) 
    df_expr_matrix.to_csv('counts.txt', sep='\t')
    
    df_meta = pd.DataFrame(data={'Cell': list(adata.obs_names), 'cell_type': list(adata.obs['Clusters'])})
    df_meta.set_index('Cell', inplace=True)
    df_meta.to_csv('meta.txt', sep='\t')

# %% [markdown]
# ## Constants

# %%
n_genes = (1000, 5000, 10000, 15000, 20000, 25000, 30000, 32738)
n_jobs = 32  # used for CellPhoneDB
n_perms = 1000
n_tests = 10
threshold = 0.1
cluster_key = 'Clusters'

# %% [markdown]
# # Load the data

# %%
adata = scv.datasets.forebrain()  # human forebrain development
adata.obs[cluster_key] = adata.obs[cluster_key].astype("category")
adata.var_names_make_unique()
adata.X = adata.X.A  # densify
adata
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# AnnData object with n_obs × n_vars = 1720 × 32738
#     obs: 'Clusters'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'

# %% [markdown]
# Normalize and create `.raw`.

# %%
sc.pp.normalize_per_cell(adata)
adata.raw = adata.copy()

# %% [markdown]
# Create gene splits.

# %%
rs = np.random.RandomState(seed=42)
geness = [rs.choice(adata.var_names, size=n_gene, replace=False) for n_gene in n_genes]

# %% [markdown]
# # Run the statistical analysis

# %% [markdown]
# ## CellPhoneDB

# %%
mean_results = defaultdict(lambda: defaultdict(dict))  # method - n_genes - split
pval_results = defaultdict(lambda: defaultdict(dict))
time_results = defaultdict(lambda: defaultdict(dict))

# %%
for genes in geness:
    print(len(genes))
    for i in range(n_tests):
        print(i)
        bdata = adata[:, genes].copy()
        save_data(bdata)

        start_t = process_time()
        statistical_analysis(
            meta_filename='meta.txt', counts_filename='counts.txt', threshold=threshold, threads=n_jobs,
            debug_seed=0, iterations=n_perms, result_precision='4', output_path='out',
            counts_data='gene_name'
        )
        duration = process_time() - start_t
        
        pval_results['cellphonedb'][bdata.n_vars][i] = pd.read_csv('out/pvalues.csv')
        mean_results['cellphonedb'][bdata.n_vars][i] = pd.read_csv('out/means.csv')
        time_results['cellphonedb'][bdata.n_vars][i] = duration
# Out:
# 1000
# 0
# [ ][APP][28/01/21-10:03:57][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:03:57][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:03:57][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:03:57][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:03:57][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:03:57][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:03:57][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:03:57][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:04:01][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:04:01][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:04:01][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:04:01][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:04:01][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:04:01][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:04:03][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:04:57][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:05:07][INFO] Building Simple results
# [ ][CORE][28/01/21-10:05:07][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:05:07][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:05:07][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:05:25][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:05:26][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:05:56][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:05:58][INFO] Building Complex results
# 1
# [ ][APP][28/01/21-10:06:20][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:06:20][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:06:20][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:06:20][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:06:20][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:06:20][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:06:20][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:06:20][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:06:24][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:06:24][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:06:24][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:06:24][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:06:24][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:06:25][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:06:26][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:07:20][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:07:29][INFO] Building Simple results
# [ ][CORE][28/01/21-10:07:29][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:07:29][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:07:29][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:07:47][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:07:48][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:08:17][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:08:19][INFO] Building Complex results
# 2
# [ ][APP][28/01/21-10:08:41][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:08:41][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:08:41][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:08:41][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:08:41][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:08:41][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:08:41][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:08:41][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:08:45][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:08:45][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:08:45][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:08:45][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:08:45][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:08:46][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:08:47][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:09:41][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:09:51][INFO] Building Simple results
# [ ][CORE][28/01/21-10:09:51][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:09:51][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:09:51][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:10:09][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:10:09][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:10:39][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:10:41][INFO] Building Complex results
# 3
# [ ][APP][28/01/21-10:11:03][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:11:03][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:11:03][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:11:03][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:11:03][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:11:03][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:11:03][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:11:03][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:11:07][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:11:07][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:11:08][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:11:08][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:11:08][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:11:08][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:11:10][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:12:05][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:12:14][INFO] Building Simple results
# [ ][CORE][28/01/21-10:12:15][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:12:15][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:12:15][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:12:33][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:12:34][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:13:04][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:13:06][INFO] Building Complex results
# 4
# [ ][APP][28/01/21-10:13:27][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:13:27][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:13:27][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:13:27][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:13:27][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:13:27][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:13:27][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:13:27][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:13:32][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:13:32][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:13:32][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:13:32][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:13:32][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:13:32][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:13:34][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:14:27][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:14:37][INFO] Building Simple results
# [ ][CORE][28/01/21-10:14:37][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:14:37][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:14:37][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:14:55][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:14:56][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:15:25][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:15:27][INFO] Building Complex results
# 5
# [ ][APP][28/01/21-10:15:49][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:15:49][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:15:49][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:15:49][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:15:49][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:15:49][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:15:49][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:15:49][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:15:53][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:15:53][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:15:54][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:15:54][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:15:54][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:15:54][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:15:56][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:16:49][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:16:58][INFO] Building Simple results
# [ ][CORE][28/01/21-10:16:59][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:16:59][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:16:59][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:17:16][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:17:17][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:17:47][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:17:49][INFO] Building Complex results
# 6
# [ ][APP][28/01/21-10:18:11][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:18:11][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:18:11][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:18:11][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:18:11][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:18:11][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:18:11][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:18:11][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:18:15][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:18:15][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:18:15][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:18:15][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:18:15][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:18:16][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:18:17][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:19:11][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:19:21][INFO] Building Simple results
# [ ][CORE][28/01/21-10:19:22][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:19:22][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:19:22][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:19:40][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:19:41][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:20:11][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:20:13][INFO] Building Complex results
# 7
# [ ][APP][28/01/21-10:20:35][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:20:35][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:20:35][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:20:35][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:20:35][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:20:35][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:20:35][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:20:35][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:20:39][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:20:39][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:20:39][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:20:39][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:20:39][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:20:40][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:20:41][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:21:36][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:21:45][INFO] Building Simple results
# [ ][CORE][28/01/21-10:21:46][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:21:46][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:21:46][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:22:03][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:22:04][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:22:33][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:22:36][INFO] Building Complex results
# 8
# [ ][APP][28/01/21-10:22:58][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:22:58][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:22:58][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:22:58][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:22:58][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:22:58][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:22:58][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:22:58][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:23:02][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:23:02][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:23:02][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:23:02][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:23:02][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:23:03][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:23:04][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:23:58][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:24:07][INFO] Building Simple results
# [ ][CORE][28/01/21-10:24:08][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:24:08][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:24:08][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:24:25][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:24:26][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:24:55][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:24:57][INFO] Building Complex results
# 9
# [ ][APP][28/01/21-10:25:19][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:25:19][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:25:19][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:25:19][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:25:19][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:25:19][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:25:19][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:25:19][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:25:23][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:25:23][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:25:24][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:25:24][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:25:24][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:25:24][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:25:26][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:26:20][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:26:30][INFO] Building Simple results
# [ ][CORE][28/01/21-10:26:31][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:26:31][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:26:31][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:26:48][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:26:49][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:27:18][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:27:20][INFO] Building Complex results
# 5000
# 0
# [ ][APP][28/01/21-10:27:43][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:27:43][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:27:43][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:27:43][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:27:43][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:27:43][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:27:43][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:27:43][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:27:47][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:27:47][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:27:48][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:27:48][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:27:48][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:27:48][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:27:49][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:28:44][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:28:53][INFO] Building Simple results
# [ ][CORE][28/01/21-10:28:54][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:28:54][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:28:54][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:29:12][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:29:13][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:29:43][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:29:45][INFO] Building Complex results
# 1
# [ ][APP][28/01/21-10:30:07][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:30:07][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:30:07][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:30:07][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:30:07][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:30:07][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:30:07][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:30:07][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:30:11][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:30:11][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:30:11][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:30:11][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:30:11][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:30:12][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:30:13][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:31:08][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:31:18][INFO] Building Simple results
# [ ][CORE][28/01/21-10:31:18][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:31:18][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:31:18][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:31:36][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:31:37][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:32:06][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:32:09][INFO] Building Complex results
# 2
# [ ][APP][28/01/21-10:32:31][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:32:31][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:32:31][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:32:31][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:32:31][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:32:31][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:32:31][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:32:31][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:32:35][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:32:35][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:32:35][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:32:35][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:32:35][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:32:36][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:32:37][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:33:31][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:33:41][INFO] Building Simple results
# [ ][CORE][28/01/21-10:33:42][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:33:42][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:33:42][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:33:59][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:34:00][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:34:30][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:34:33][INFO] Building Complex results
# 3
# [ ][APP][28/01/21-10:34:57][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:34:57][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:34:57][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:34:57][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:34:57][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:34:57][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:34:57][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:34:57][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:35:02][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:35:02][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:35:02][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:35:02][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:35:02][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:35:02][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:35:04][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:35:56][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:36:06][INFO] Building Simple results
# [ ][CORE][28/01/21-10:36:07][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:36:07][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:36:07][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:36:24][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:36:25][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:36:55][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:36:58][INFO] Building Complex results
# 4
# [ ][APP][28/01/21-10:37:22][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:37:22][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:37:22][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:37:22][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:37:22][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:37:22][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:37:22][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:37:22][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:37:27][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:37:27][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:37:28][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:37:28][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:37:28][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:37:28][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:37:29][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:38:23][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:38:33][INFO] Building Simple results
# [ ][CORE][28/01/21-10:38:33][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:38:33][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:38:33][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:38:51][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:38:52][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:39:22][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:39:24][INFO] Building Complex results
# 5
# [ ][APP][28/01/21-10:39:48][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:39:48][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:39:48][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:39:48][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:39:48][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:39:48][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:39:48][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:39:48][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:39:52][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:39:52][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:39:52][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:39:52][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:39:52][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:39:53][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:39:54][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:40:48][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:40:58][INFO] Building Simple results
# [ ][CORE][28/01/21-10:40:59][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:40:59][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:40:59][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:41:17][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:41:18][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:41:47][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:41:50][INFO] Building Complex results
# 6
# [ ][APP][28/01/21-10:42:12][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:42:12][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:42:12][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:42:12][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:42:12][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:42:12][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:42:12][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:42:12][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:42:16][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:42:16][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:42:16][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:42:16][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:42:16][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:42:17][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:42:18][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:43:13][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:43:23][INFO] Building Simple results
# [ ][CORE][28/01/21-10:43:24][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:43:24][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:43:24][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:43:42][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:43:43][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:44:12][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:44:15][INFO] Building Complex results
# 7
# [ ][APP][28/01/21-10:44:37][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:44:37][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:44:37][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:44:37][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:44:37][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:44:37][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:44:37][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:44:37][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:44:41][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:44:41][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:44:42][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:44:42][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:44:42][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:44:42][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:44:43][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:45:37][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:45:47][INFO] Building Simple results
# [ ][CORE][28/01/21-10:45:47][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:45:47][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:45:47][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:46:05][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:46:06][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:46:36][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:46:38][INFO] Building Complex results
# 8
# [ ][APP][28/01/21-10:47:00][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:47:00][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:47:00][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:47:00][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:47:00][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:47:00][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:47:00][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:47:00][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:47:04][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:47:04][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:47:05][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:47:05][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:47:05][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:47:05][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:47:07][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:48:00][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:48:10][INFO] Building Simple results
# [ ][CORE][28/01/21-10:48:10][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:48:10][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:48:10][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:48:29][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:48:30][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:48:59][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:49:02][INFO] Building Complex results
# 9
# [ ][APP][28/01/21-10:49:24][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:49:24][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:49:24][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:49:24][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:49:24][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:49:24][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:49:24][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:49:24][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:49:29][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:49:29][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:49:29][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:49:29][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:49:29][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:49:29][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:49:31][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:50:26][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:50:35][INFO] Building Simple results
# [ ][CORE][28/01/21-10:50:36][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:50:36][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:50:36][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:50:53][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:50:54][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:51:23][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:51:25][INFO] Building Complex results
# 10000
# 0
# [ ][APP][28/01/21-10:51:47][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:51:47][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:51:47][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:51:47][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:51:47][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:51:47][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:51:47][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:51:47][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:51:52][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:51:52][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:51:52][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:51:52][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:51:52][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:51:53][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:51:54][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:52:48][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:52:57][INFO] Building Simple results
# [ ][CORE][28/01/21-10:52:57][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:52:57][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:52:57][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:53:15][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:53:16][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:53:45][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:53:48][INFO] Building Complex results
# 1
# [ ][APP][28/01/21-10:54:10][WARNING] Latest local available version is `v2.0.0`, using it
# [ ][APP][28/01/21-10:54:10][WARNING] User selected downloaded database `v2.0.0` is available, using it
# [ ][CORE][28/01/21-10:54:10][INFO] Initializing SqlAlchemy CellPhoneDB Core
# [ ][CORE][28/01/21-10:54:10][INFO] Using custom database at /home/marius.lange/.cpdb/releases/v2.0.0/cellphone.db
# [ ][APP][28/01/21-10:54:10][INFO] Launching Method cpdb_statistical_analysis_local_method_launcher
# [ ][APP][28/01/21-10:54:10][INFO] Launching Method _set_paths
# [ ][APP][28/01/21-10:54:10][WARNING] Output directory (out) exist and is not empty. Result can overwrite old results
# [ ][APP][28/01/21-10:54:10][INFO] Launching Method _load_meta_counts
# [ ][CORE][28/01/21-10:54:14][INFO] Launching Method cpdb_statistical_analysis_launcher
# [ ][CORE][28/01/21-10:54:14][INFO] Launching Method _counts_validations
# [ ][CORE][28/01/21-10:54:15][INFO] [Cluster Statistical Analysis Simple] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:54:15][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:54:15][INFO] Running Simple Prefilters
# [ ][CORE][28/01/21-10:54:15][INFO] Running Real Simple Analysis
# [ ][CORE][28/01/21-10:54:16][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:55:10][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:55:19][INFO] Building Simple results
# [ ][CORE][28/01/21-10:55:20][INFO] [Cluster Statistical Analysis Complex] Threshold:0.1 Iterations:1000 Debug-seed:0 Threads:32 Precision:4
# [ ][CORE][28/01/21-10:55:20][WARNING] Debug random seed enabled. Setted to 0
# [ ][CORE][28/01/21-10:55:20][INFO] Running Complex Prefilters
# [ ][CORE][28/01/21-10:55:37][INFO] Running Real Complex Analysis
# [ ][CORE][28/01/21-10:55:38][INFO] Running Statistical Analysis
# [ ][CORE][28/01/21-10:56:08][INFO] Building Pvalues result
# [ ][CORE][28/01/21-10:56:10][INFO] Building Complex results
# 2

# %% [markdown]
# ## Squidpy's reimplementation of CellPhoneDB

# %%
for genes in geness:
    print(len(genes))
    for i in range(n_tests):
        print(i)
        bdata = adata[:, genes].copy()

        start_t = process_time()
        res = sq.gr.ligrec(
            adata,
            n_perms=n_perms,
            threshold=threshold,
            cluster_key="Clusters",
            copy=True,
            use_raw=False,
            show_progress_bar=False,
            interactions_params={'resources': 'CellPhoneDB'},
            transmitter_params={"categories": "ligand"},
            receiver_params={"categories": "receptor"},
            numba_parallel=False,
            n_jobs=n_jobs,
        )
        duration = process_time() - start_t
        
        pval_results['squidpy'][bdata.n_vars][i] = res.pvalues
        mean_results['squidpy'][bdata.n_vars][i] = res.means
        time_results['squidpy'][bdata.n_vars][i] = duration

# %% [markdown]
# # Save the results

# %%
dfs = []
for meth, split in time_results.items():
    tmp = pd.DataFrame(split)
    mean, std = tmp.mean(), tmp.std()
    ms = pd.DataFrame([[val for pair in zip(mean, std) for val in pair]],
                      columns=[f"{c} {k}" for c in mean.index for k in ["mean", "std"]],
                      index=[meth])
    dfs.append(ms)
    
df = pd.concat(dfs)
df

# %%
with open("resuls.pickle", "wb") as fout:
    pickle.dump((pval_results, mean_results, time_results, df), fout)

# %% [markdown]
# # Plot the average runtimes

# %%
fig, ax = plt.subplots(tight_layout=True, dpi=180)
ax.plot(n_genes, df.values[0], label='CellPhoneDB')
ax.plot(n_genes, df.values[1], label='Squidpy')
ax.set_ylabel('runtime (s)')
ax.set_xlabel('#genes')
ax.legend()
_ = ax.set_title('comparisons of runtimes')
