# %%
import scanpy as sc
import matplotlib.pyplot as plt
import pandas as pd
import pathlib

# %%
BASE_PATH = pathlib.Path(
    "/Users/giovanni.palla/dataset_raw_icb/20201214_SquidpyData_giovanni.palla"
)
DATA_PATH = "IMC"

# %%
adata = sc.read(BASE_PATH / DATA_PATH / "bz_image_3.h5ad")

# %%
sc.pl.spatial(adata, color="cell type", spot_size=10)

# %%
sel = adata.obs["cell type"].value_counts()[adata.obs["cell type"].value_counts() > 20].index.values
adata = adata[adata.obs["cell type"].isin(sel)].copy()
adata.raw = adata
# Out:
# /Users/giovanni.palla/miniconda3/envs/spatial/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
sc.pl.spatial(adata, color="cell type", spot_size=10)

# %%
adata.write("/Users/giovanni.palla/Datasets/tutorial_data/imc.h5ad")

# %%
adata = sc.read("/Users/giovanni.palla/Datasets/tutorial_data/imc.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 4668 × 34
#     obs: 'cell type'
#     uns: 'cell type_colors'
#     obsm: 'spatial'
