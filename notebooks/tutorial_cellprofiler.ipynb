# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Analyze Visium fluorescence data | CellProfiler integration
#
# In this tutorial we show how to use squidpy with functions of [cellprofiler](https://cellprofiler.org) pipelines for image processing and feature extraction.
#
# Cellprofiler is typically used via it's GUI interface to build image processing pipelines.
# First download and install Cellprofiler from the [download page](https://github.com/CellProfiler/CellProfiler). Check issues on the [CellProfiler Github](https://github.com/CellProfiler/CellProfiler/issues) in case of installation problems (can be tricky).
#
# Note: In the future Cellprofiler functions will also be accessible via python code (according announcements of the Cellprofiler team). Since this is not publically well documented yet we'll restrict this tutorial to the laborious way of saveing intermediate files to bridge between squidpy and Cellprofiler. For infos how to use the `cellprofiler-core` package for python integration the following [link](https://github.com/CellProfiler/CellProfiler/wiki/CellProfiler-as-a-Python-package) might be helpful.
#
# We'll go through the following steps:
# 1. Load visium fluorescence data
# 2. Segment cells in squidpy
# 3. Calculate CellProfiler's granularity features for image crops of visium spots
# 4. Compute clustering on the image features in squidpy

# %% [markdown]
# # Import packages & data

# %%
#import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
import squidpy as sq
import matplotlib.pyplot as plt
from pathlib import Path

sc.logging.print_header()
print(f"squidpy=={sq.__version__}")
sc.set_figure_params(facecolor="white", figsize=(8, 8))

# load the pre-processed dataset
img = sq.datasets.visium_fluo_image_crop()
adata = sq.datasets.visium_fluo_adata_crop()
# Out:
# scanpy==1.7.2 anndata==0.7.6 umap==0.5.1 numpy==1.20.2 scipy==1.6.3 pandas==1.2.4 scikit-learn==0.24.2 statsmodels==0.12.2 python-igraph==0.9.1
# squidpy==1.0.0

# %%
sc.pl.spatial(adata, color="cluster")

# %% [markdown]
# # Setup files
# Create some arbitrary empty base directory `BASE_DIR` and a folder `"tmp_imgs"` in it.

# %%
BASE_DIR = './squidpy_tutorial_cellprofiler/'
Path(BASE_DIR).mkdir(parents=True, exist_ok=True)
Path(BASE_DIR+'tmp_imgs/').mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Open the CellProfiler GUI App. A new project should open automatically:
# ![title](tutorial_cellprofiler_images/01CP_new_project.png)
# Save the project in `BASE_DIR`
# ![title](tutorial_cellprofiler_images/02CP_save_project.png)

# %% [markdown]
# # Image segmentation

# %%
sq.im.process(
    img=img,
    layer="image",
    method="smooth",
)

sq.im.segment(img=img, layer="image_smooth", method="watershed", channel_ids=0, xs=1000, ys=1000)

# plot the resulting segmentation
fig, ax = plt.subplots(1, 2)
img_crop = img.crop_corner(2000, 2000, size=500)
img_crop.show(layer="image", channel=0, ax=ax[0])
img_crop.show(
    layer="segmented_watershed",
    channel=0,
    ax=ax[1],
)

# %% [markdown]
# # Save image crops and segmentations
# For each visium spot we generate crops:

# %%
for i,(crop,obs) in enumerate(img.generate_spot_crops(adata, obs_names=adata.obs_names, return_obs=True, as_array=False)):
    if i < 2:
        fig, axes = plt.subplots(1, 2)
        axes[0].imshow(crop['image_smooth'])
        axes[1].imshow(crop['segmented_watershed'][:,:,0],cmap='Greys')
        plt.show()
    if i == 2:
        break

# %% [markdown]
# Save the fluorescence image and the segmentations of each crop

# %%
for i,(crop,obs) in enumerate(img.generate_spot_crops(adata, obs_names=adata.obs_names, return_obs=True, as_array=False)):
    Image.fromarray((np.array(crop['image_smooth'])* 255).astype(np.uint8)).save(BASE_DIR+f'tmp_imgs/image_{obs}.png')
    Image.fromarray(np.array(crop['segmented_watershed'][:,:,0])).save(BASE_DIR+f'tmp_imgs/segments_{obs}.tif')

# %% [markdown]
# # CellProfiler Pipeline: Calculate Image Features
# 1. CP-Pipeline `Images`: Drag and Drop the folder `BASE_DIR+"tmp_imgs"` into CellProfiler
# ![title](tutorial_cellprofiler_images/03CP_import_images.png)
# 2. CP-Pipeline `NamesAndTypes`: Declare to load crops as colour images and segmentations as objects. Crops and segmentations files are aligned automatically.
# ![title](tutorial_cellprofiler_images/04CP_NamesAndTypes.png)
# 3. Convert image crops to gray images: Add `ColorToGray` module and define parameters.
# ![title](tutorial_cellprofiler_images/05CP_Create_ColorToGray.png)
# ![title](tutorial_cellprofiler_images/06CP_ColorToGray.png)
# 4. Measure CellProfiler's Granularity features within segments for each crop: Add `MeasureGranularity` module and define parameters.
# ![title](tutorial_cellprofiler_images/07CP_Create_Granularity.png)
# ![title](tutorial_cellprofiler_images/08CP_Granularity.png)
# 5. Export results to csv.
# ![title](tutorial_cellprofiler_images/09CP_Create_Export.png)
# ![title](tutorial_cellprofiler_images/10CP_Export.png)
# 6. Run CellProfiler Pipeline (takes several minutes).
# ![title](tutorial_cellprofiler_images/11CP_Run.png)
# You can delete the images in `BASE_DIR+"tmp_imgs/"` now.

# %% [markdown]
# # Cluster features
# Load CellProfiler output of Granularity features of each visium spot and rearange the output for `adata.obsm`.

# %%
# load Cellprofiler output
df = pd.read_csv(BASE_DIR+'/squidpy_Image.csv')
# set obs names as index
df.index = df['FileName_Spot_Crop'].apply(lambda s: s.split("_")[1].split(".")[0])
df.index.name = "obs"
# Get the measured Granularity features and rename them
features = [f'{stat}_Segments_Granularity_{i}_SpotGray' for stat in ['Mean','StDev'] for i in range(1,17)]
df = df[features]
df.columns = [s.split("_")[0]+s.split("_")[2]+s.split("_")[3] for s in df.columns]

# %%
df.head()
# Out:
#                     MeanGranularity1  MeanGranularity2  MeanGranularity3  \
# obs
# AAACGAGACGGTTGAT-1         35.513010          8.562676         26.546550
# AAAGGGATGTAGCAAG-1         34.115594         24.218906         20.290728
# AAATGGCATGTCTTGT-1         35.680015         15.708321         15.551889
# AAATGGTCAATGTGCC-1         27.243626          6.490712          9.602902
# AAATTAACGGGTAGCT-1         33.575662         12.159623         21.226989
#
#                     MeanGranularity4  MeanGranularity5  MeanGranularity6  \
# obs
# AAACGAGACGGTTGAT-1         14.187602          7.629247          3.334912
# AAAGGGATGTAGCAAG-1          4.457829          0.832083          4.670038
# AAATGGCATGTCTTGT-1          8.760072          5.392920          7.575340
# AAATGGTCAATGTGCC-1          3.852946          3.829664          0.000000
# AAATTAACGGGTAGCT-1         19.807115          8.313644          2.021116
#
#                     MeanGranularity7  MeanGranularity8  MeanGranularity9  \
# obs
# AAACGAGACGGTTGAT-1          2.057867          0.623025          0.258596
# AAAGGGATGTAGCAAG-1          3.027418          1.872175          0.694657
# AAATGGCATGTCTTGT-1          5.474114          0.876559          0.121634
# AAATGGTCAATGTGCC-1          0.000000          7.289044          8.814914
# AAATTAACGGGTAGCT-1          0.463706          0.716149          0.283679
#
#                     MeanGranularity10  ...  StDevGranularity7  \
# obs                                    ...
# AAACGAGACGGTTGAT-1           0.336359  ...           1.615079
# AAAGGGATGTAGCAAG-1           0.642282  ...           4.840615
# AAATGGCATGTCTTGT-1           0.000000  ...           2.082841
# AAATGGTCAATGTGCC-1          12.036803  ...           0.000000
# AAATTAACGGGTAGCT-1           0.283679  ...           0.328582
#
#                     StDevGranularity8  StDevGranularity9  StDevGranularity10  \
# obs
# AAACGAGACGGTTGAT-1           0.490024           0.284772            0.251887
# AAAGGGATGTAGCAAG-1           2.934531           1.024722            1.045698
# AAATGGCATGTCTTGT-1           1.640197           0.227598            0.000000
# AAATGGTCAATGTGCC-1           9.020724           6.604276            3.711367
# AAATTAACGGGTAGCT-1           0.264752           0.219188            0.219188
#
#                     StDevGranularity11  StDevGranularity12  \
# obs
# AAACGAGACGGTTGAT-1            0.000000            0.000000
# AAAGGGATGTAGCAAG-1            0.174283            0.783332
# AAATGGCATGTCTTGT-1            0.392862            0.785725
# AAATGGTCAATGTGCC-1            1.988622            1.063700
# AAATTAACGGGTAGCT-1            0.000000            0.000000
#
#                     StDevGranularity13  StDevGranularity14  \
# obs
# AAACGAGACGGTTGAT-1            0.000000            0.196002
# AAAGGGATGTAGCAAG-1            0.156181            0.156181
# AAATGGCATGTCTTGT-1            1.172769            0.234967
# AAATGGTCAATGTGCC-1            0.303914            0.075979
# AAATTAACGGGTAGCT-1            0.219188            0.000000
#
#                     StDevGranularity15  StDevGranularity16
# obs
# AAACGAGACGGTTGAT-1            0.000000                 0.0
# AAAGGGATGTAGCAAG-1            0.156181                 0.0
# AAATGGCATGTCTTGT-1            0.000000                 0.0
# AAATGGTCAATGTGCC-1            0.151957                 0.0
# AAATTAACGGGTAGCT-1            0.000000                 0.0
#
# [5 rows x 32 columns]

# %% [markdown]
# Load image features into `adata.obsm["features"]` and compute leiden clustering

# %%
def cluster_features(features: pd.DataFrame):
    """Calculate leiden clustering of features.
    """
    # create temporary adata to calculate the clustering
    adata = ad.AnnData(features)
    # important - feature values are not scaled, so need to scale them before PCA
    sc.pp.scale(adata)
    # calculate leiden clustering
    sc.pp.pca(adata, n_comps=min(10, features.shape[1] - 1))
    sc.pp.neighbors(adata)
    sc.tl.leiden(adata)

    return adata.obs["leiden"]

# Save feature in adata.obsm
adata.obsm["features"] = df.loc[adata.obs_names].copy()

# Calculate leiden clustering
adata.obs["features_granularity_cluster"] = cluster_features(adata.obsm["features"])

# Plot clusterings
sc.pl.spatial(
    adata,
    color=[
        "features_granularity_cluster",
        "cluster",
    ],
    ncols=2,
)

# %% [markdown]
# We see that e.g. the blue cluster is prominent in the Hippocampus and the Thalamus, and the brown cluster is prominent in dense regions like Dentate gyrus.
